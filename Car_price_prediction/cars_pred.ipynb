# %%
import pandas as pd

# %%
df = pd.read_csv('car_price_prediction.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19237 entries, 0 to 19236
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID                19237 non-null  int64
#  1   Price             19237 non-null  int64
#  2   Levy              19237 non-null  object
#  3   Manufacturer      19237 non-null  object
#  4   Model             19237 non-null  object
#  5   Prod. year        19237 non-null  int64
#  6   Category          19237 non-null  object
#  7   Leather interior  19237 non-null  object
#  8   Fuel type         19237 non-null  object
#  9   Engine volume     19237 non-null  object
#  10  Mileage           19237 non-null  object
#  11  Cylinders         19237 non-null  float64
#  12  Gear box type     19237 non-null  object
#  13  Drive wheels      19237 non-null  object
#  14  Doors             19237 non-null  object
#  15  Wheel             19237 non-null  object
#  16  Color             19237 non-null  object
#  17  Airbags           19237 non-null  int64
# dtypes: float64(1), int64(4), object(13)
# memory usage: 2.6+ MB

# %%
df.drop(['ID', 'Levy', 'Leather interior', 'Doors', 'Wheel'], axis=1, inplace=True)

# %%
df
# Out:
#        Price   Manufacturer    Model  Prod. year   Category Fuel type  \
# 0      13328          LEXUS   RX 450        2010       Jeep    Hybrid
# 1      16621      CHEVROLET  Equinox        2011       Jeep    Petrol
# 2       8467          HONDA      FIT        2006  Hatchback    Petrol
# 3       3607           FORD   Escape        2011       Jeep    Hybrid
# 4      11726          HONDA      FIT        2014  Hatchback    Petrol
# ...      ...            ...      ...         ...        ...       ...
# 19232   8467  MERCEDES-BENZ  CLK 200        1999      Coupe       CNG
# 19233  15681        HYUNDAI   Sonata        2011      Sedan    Petrol
# 19234  26108        HYUNDAI   Tucson        2010       Jeep    Diesel
# 19235   5331      CHEVROLET  Captiva        2007       Jeep    Diesel
# 19236    470        HYUNDAI   Sonata        2012      Sedan    Hybrid
#
#       Engine volume    Mileage  Cylinders Gear box type Drive wheels   Color  \
# 0               3.5  186005 km        6.0     Automatic          4x4  Silver
# 1                 3  192000 km        6.0     Tiptronic          4x4   Black
# 2               1.3  200000 km        4.0      Variator        Front   Black
# 3               2.5  168966 km        4.0     Automatic          4x4   White
# 4               1.3   91901 km        4.0     Automatic        Front  Silver
# ...             ...        ...        ...           ...          ...     ...
# 19232     2.0 Turbo  300000 km        4.0        Manual         Rear  Silver
# 19233           2.4  161600 km        4.0     Tiptronic        Front     Red
# 19234             2  116365 km        4.0     Automatic        Front    Grey
# 19235             2   51258 km        4.0     Automatic        Front   Black
# 19236           2.4  186923 km        4.0     Automatic        Front   White
#
#        Airbags
# 0           12
# 1            8
# 2            2
# 3            0
# 4            4
# ...        ...
# 19232        5
# 19233        8
# 19234        4
# 19235        4
# 19236       12
#
# [19237 rows x 13 columns]

# %%
def eng_vol(value):
    if 'Turbo' in value:
        value = value.replace('Turbo', '')
        return  float(value)
    else:
        return  float(value)
df['Engine volume'] = df['Engine volume'].map(eng_vol)

# %%
def conv_mil(value):
    if 'km' in value:
        value = value.replace('km', '')
        return float(value)
    else:
        return float(value)

df['Mileage'] = df['Mileage'].apply(conv_mil)

# %%
df
# Out:
#        Price   Manufacturer    Model  Prod. year   Category Fuel type  \
# 0      13328          LEXUS   RX 450        2010       Jeep    Hybrid
# 1      16621      CHEVROLET  Equinox        2011       Jeep    Petrol
# 2       8467          HONDA      FIT        2006  Hatchback    Petrol
# 3       3607           FORD   Escape        2011       Jeep    Hybrid
# 4      11726          HONDA      FIT        2014  Hatchback    Petrol
# ...      ...            ...      ...         ...        ...       ...
# 19232   8467  MERCEDES-BENZ  CLK 200        1999      Coupe       CNG
# 19233  15681        HYUNDAI   Sonata        2011      Sedan    Petrol
# 19234  26108        HYUNDAI   Tucson        2010       Jeep    Diesel
# 19235   5331      CHEVROLET  Captiva        2007       Jeep    Diesel
# 19236    470        HYUNDAI   Sonata        2012      Sedan    Hybrid
#
#        Engine volume   Mileage  Cylinders Gear box type Drive wheels   Color  \
# 0                3.5  186005.0        6.0     Automatic          4x4  Silver
# 1                3.0  192000.0        6.0     Tiptronic          4x4   Black
# 2                1.3  200000.0        4.0      Variator        Front   Black
# 3                2.5  168966.0        4.0     Automatic          4x4   White
# 4                1.3   91901.0        4.0     Automatic        Front  Silver
# ...              ...       ...        ...           ...          ...     ...
# 19232            2.0  300000.0        4.0        Manual         Rear  Silver
# 19233            2.4  161600.0        4.0     Tiptronic        Front     Red
# 19234            2.0  116365.0        4.0     Automatic        Front    Grey
# 19235            2.0   51258.0        4.0     Automatic        Front   Black
# 19236            2.4  186923.0        4.0     Automatic        Front   White
#
#        Airbags
# 0           12
# 1            8
# 2            2
# 3            0
# 4            4
# ...        ...
# 19232        5
# 19233        8
# 19234        4
# 19235        4
# 19236       12
#
# [19237 rows x 13 columns]

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
import joblib
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import make_pipeline

# %%
x = df.drop('Price', axis=1)
y = df['Price']

# %%
x_train, x_test, y_train, y_test, = train_test_split(x,y, test_size=0.25, random_state=42)

# %%
sc = StandardScaler()

# %%
oe = OneHotEncoder(handle_unknown='ignore')

# %%
numeric_features = x_train.select_dtypes(include='int64').columns
print(numeric_features)
# Out:
# Index(['Prod. year', 'Airbags'], dtype='object')

# %%
categorical_features = x_train.select_dtypes(include='object').columns
print(categorical_features)
# Out:
# Index(['Manufacturer', 'Model', 'Category', 'Fuel type', 'Gear box type',
#        'Drive wheels', 'Color'],
#       dtype='object')

# %%
preprocessor = ColumnTransformer(
    transformers=[
        ('num', sc, numeric_features),
        ('cat', oe, categorical_features)
    ]
)

# %%
model = make_pipeline(preprocessor, LinearRegression())
print(model)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(transformers=[('num', StandardScaler(),
#                                                   Index(['Prod. year', 'Airbags'], dtype='object')),
#                                                  ('cat',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   Index(['Manufacturer', 'Model', 'Category', 'Fuel type', 'Gear box type',
#        'Drive wheels', 'Color'],
#       dtype='object'))])),
#                 ('linearregression', LinearRegression())])

# %%
model.fit(x_train, y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(transformers=[('num', StandardScaler(),
#                                                   Index(['Prod. year', 'Airbags'], dtype='object')),
#                                                  ('cat',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   Index(['Manufacturer', 'Model', 'Category', 'Fuel type', 'Gear box type',
#        'Drive wheels', 'Color'],
#       dtype='object'))])),
#                 ('linearregression', LinearRegression())])

# %%
preds = model.predict(x_test)

# %%
import numpy as np
mse = mean_squared_error(y_test, preds)
print(f"MSE:{np.sqrt(mse)}")
# Out:
# MSE:37892.081570141934

# %%
joblib.dump(model, 'cars_prices_predictions.joblib')
# Out:
# ['cars_prices_predictions.joblib']

# %%
loaded_model = joblib.load('cars_prices_predictions.joblib')

# %%
df1 = pd.DataFrame({
    'Manufacturer':['CHEVROLET'],
    'Model':['Captiva'],
    'Prod. year':[2015],
    'Category':['Jeep'],
    'Fuel type':['Petrol'],
    'Engine volume':[4.0],
    'Mileage':[100000],
    'Cylinders':[4.0],
    'Gear box type':['Manual'],
    'Drive wheels':['Rear'],
    'Color':['Black'],
    'Airbags':[2],
})
new_pred = loaded_model.predict(df1)
print(new_pred[0])
# Out:
# 2807.9210032553674

# %%
df
# Out:
#        Price   Manufacturer    Model  Prod. year   Category Fuel type  \
# 0      13328          LEXUS   RX 450        2010       Jeep    Hybrid
# 1      16621      CHEVROLET  Equinox        2011       Jeep    Petrol
# 2       8467          HONDA      FIT        2006  Hatchback    Petrol
# 3       3607           FORD   Escape        2011       Jeep    Hybrid
# 4      11726          HONDA      FIT        2014  Hatchback    Petrol
# ...      ...            ...      ...         ...        ...       ...
# 19232   8467  MERCEDES-BENZ  CLK 200        1999      Coupe       CNG
# 19233  15681        HYUNDAI   Sonata        2011      Sedan    Petrol
# 19234  26108        HYUNDAI   Tucson        2010       Jeep    Diesel
# 19235   5331      CHEVROLET  Captiva        2007       Jeep    Diesel
# 19236    470        HYUNDAI   Sonata        2012      Sedan    Hybrid
#
#        Engine volume   Mileage  Cylinders Gear box type Drive wheels   Color  \
# 0                3.5  186005.0        6.0     Automatic          4x4  Silver
# 1                3.0  192000.0        6.0     Tiptronic          4x4   Black
# 2                1.3  200000.0        4.0      Variator        Front   Black
# 3                2.5  168966.0        4.0     Automatic          4x4   White
# 4                1.3   91901.0        4.0     Automatic        Front  Silver
# ...              ...       ...        ...           ...          ...     ...
# 19232            2.0  300000.0        4.0        Manual         Rear  Silver
# 19233            2.4  161600.0        4.0     Tiptronic        Front     Red
# 19234            2.0  116365.0        4.0     Automatic        Front    Grey
# 19235            2.0   51258.0        4.0     Automatic        Front   Black
# 19236            2.4  186923.0        4.0     Automatic        Front   White
#
#        Airbags
# 0           12
# 1            8
# 2            2
# 3            0
# 4            4
# ...        ...
# 19232        5
# 19233        8
# 19234        4
# 19235        4
# 19236       12
#
# [19237 rows x 13 columns]
