# %%
import pandas as pd

# %%
df = pd.read_csv('laptops_cleaned.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112 entries, 0 to 111
# Data columns (total 13 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Unnamed: 0.1                      112 non-null    int64
#  1   Unnamed: 0                        112 non-null    int64
#  2   laptop-brand                      112 non-null    object
#  3   laptop-model                      112 non-null    object
#  4   laptop-screensize                 112 non-null    float64
#  5   laptop-ram                        112 non-null    int64
#  6   laptop-storage                    112 non-null    int64
#  7   laptop-cpu                        112 non-null    object
#  8   laptop-operating_system           112 non-null    object
#  9   laptop-price                      112 non-null    float64
#  10  laptop-rating                     112 non-null    float64
# ...

# %%
# df.drop(['Unnamed: 0.1', 'Unnamed: 0'], axis=1)
df.drop(columns=['Unnamed: 0.1', 'Unnamed: 0'], inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112 entries, 0 to 111
# Data columns (total 11 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   laptop-brand                      112 non-null    object
#  1   laptop-model                      112 non-null    object
#  2   laptop-screensize                 112 non-null    float64
#  3   laptop-ram                        112 non-null    int64
#  4   laptop-storage                    112 non-null    int64
#  5   laptop-cpu                        112 non-null    object
#  6   laptop-operating_system           112 non-null    object
#  7   laptop-price                      112 non-null    float64
#  8   laptop-rating                     112 non-null    float64
#  9   laptop-review_count               112 non-null    int64
#  10  laptop-graphics_card_description  112 non-null    object
# dtypes: float64(3), int64(3), object(5)
# ...

# %%
# Gipotiza
# G-1 YUQORI NARXLI LAPTOPLAR YUQORI RATINGA EGA

# %%
higer_price = df['laptop-price'].mean() # 62194.75

# %%
higer_price # 62194.75
# Out:
# 62194.75

# %%
# higer_price = df['laptop-price'].mean()
# higer_price   # 62194.75
# higer_rating = df['laptop-rating'].mean()
# higer_rating  #3.9482142857142857
df.set_index('laptop-brand')
# Out:
#                  laptop-model  laptop-screensize  laptop-ram  laptop-storage  \
# laptop-brand
# Lenovo        Lenovo ThinkPad             35.560          16             512
# acer              Aspire Lite             39.624          16             512
# Apple             MacBook Air             33.020          16             256
# HP                  HP Laptop             39.600          16             512
# Dell            Dell Latitude             33.782          32             256
# ...                       ...                ...         ...             ...
# Microsoft            Laptop 4             33.020          16             512
# ASUS           Vivobook Go 14             35.560           8             512
# Lenovo                Ideapad             39.624          12             512
# ARZOPA             Lenovo V15             39.624           8             256
# HP                16-xf0060AX            103.886          16            1024
#
# ...

# %%
higer_rating = df['laptop-rating'].mean()
# higer_price # 62194.75
higer_rating  #3.9482142857142857
# Out:
# 3.9482142857142857

# %%
total = df[df['laptop-price'] >= higer_price]
# total da df[df['laptop-price'] >= higer_price] shu shartni qanoatlantiradigan qiymaylar saqlanmoqda
total.set_index('laptop-model', inplace=True)

# %%
result_two_cloumn = total[['laptop-price', 'laptop-rating']]
res1 = result_two_cloumn[['laptop-price', 'laptop-rating']]

# %%
rating_higer = res1[res1['laptop-rating'] >= higer_rating]
rating_lower = res1[res1['laptop-rating'] <= higer_rating]
rating_higer.count()
# rating_lower.value_counts()
# Out:
# laptop-price     20
# laptop-rating    20
# dtype: int64

# %%
rating_lower.sum()
# Out:
# laptop-price     1490009.0
# laptop-rating         37.2
# dtype: float64

# %%
import matplotlib.pyplot as plt
ax = res1.plot(kind='line', y='laptop-rating', x='laptop-price')

# Now, set the y-ticks
# ax.set_yticks([0, 0.5, 1, 1.5, 2, 2.5, 3, 3.5, 4, 4.5, 5])

# %%
res1.plot(kind='pie', x='laptop-rating', y='laptop-price')
# import matplotlib.pyplot as plt
# res1.plot(kind='bar', x='laptop-price', y='laptop-rating')
# Out:
# <Axes: ylabel='laptop-price'>

# %%
# import matplotlib.pyplot as plt
# total[['laptop-price', 'laptop-rating']].plot.scatter(title='# G-1 YUQORI NARXLI LAPTOPLAR YUQORI RATINGA EGA', x='laptop-price', y='laptop-rating')
# Out:
# <Axes: title={'center': '# G-1 YUQORI NARXLI LAPTOPLAR YUQORI RATINGA EGA'}, xlabel='laptop-price', ylabel='laptop-rating'>

# %%
total[['laptop-price', 'laptop-rating']].plot(kind = 'hist',title='# G-1 YUQORI NARXLI LAPTOPLAR YUQORI RATINGA EGA', x='laptop-price', y='laptop-rating', bins = 10)
# Out:
# <Axes: title={'center': '# G-1 YUQORI NARXLI LAPTOPLAR YUQORI RATINGA EGA'}, ylabel='Frequency'>
